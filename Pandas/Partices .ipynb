# %%
import pandas as pd

# %%
data = pd.read_csv('E:\\MACHIN LEARING\\DataSets\\test_identity.csv')
data
# Out:
#         TransactionID  id-01     id-02  id-03  id-04  id-05  id-06  id-07  \
# 0             3663586  -45.0  280290.0    NaN    NaN    0.0    0.0    NaN
# 1             3663588    0.0    3579.0    0.0    0.0    0.0    0.0    NaN
# 2             3663597   -5.0  185210.0    NaN    NaN    1.0    0.0    NaN
# 3             3663601  -45.0  252944.0    0.0    0.0    0.0    0.0    NaN
# 4             3663602  -95.0  328680.0    NaN    NaN    7.0  -33.0    NaN
# ...               ...    ...       ...    ...    ...    ...    ...    ...
# 141902        4170230  -20.0  473365.0    NaN    NaN    0.0    0.0    NaN
# 141903        4170233   -5.0  489917.0    0.0    0.0   -4.0  -32.0    NaN
# 141904        4170234   -5.0  110081.0    NaN    NaN   22.0  -31.0    NaN
# 141905        4170236  -45.0  266704.0    NaN    NaN   -3.0  -10.0    NaN
# 141906        4170239  -10.0  692090.0    0.0    0.0    0.0    0.0    NaN
#
#         id-08  id-09  ...                    id-31  id-32     id-33  \
# ...

# %%
data.columns
# Out:
# Index(['TransactionID', 'id-01', 'id-02', 'id-03', 'id-04', 'id-05', 'id-06',
#        'id-07', 'id-08', 'id-09', 'id-10', 'id-11', 'id-12', 'id-13', 'id-14',
#        'id-15', 'id-16', 'id-17', 'id-18', 'id-19', 'id-20', 'id-21', 'id-22',
#        'id-23', 'id-24', 'id-25', 'id-26', 'id-27', 'id-28', 'id-29', 'id-30',
#        'id-31', 'id-32', 'id-33', 'id-34', 'id-35', 'id-36', 'id-37', 'id-38',
#        'DeviceType', 'DeviceInfo'],
#       dtype='object')

# %%
data.isna().sum()
# Out:
# TransactionID         0
# id-01                 0
# id-02              4931
# id-03             75426
# id-04             75426
# id-05              7157
# id-06              7157
# id-07            136848
# id-08            136848
# id-09             67569
# id-10             67569
# id-11              5129
# id-12                 0
# id-13             11621
# id-14             70550
# id-15              4930
# id-16             16160
# id-17              5941
# id-18             91032
# id-19              6001
# id-20              6274
# id-21            136848
# id-22            136845
# id-23            136845
# id-24            137167
# id-25            136868
# id-26            136860
# id-27            136845
# id-28              5129
# id-29              5129
# id-30             71248
# id-31              5282
# id-32             71236
# id-33             71236
# id-34             69732
# id-35              4930
# id-36              4930
# id-37              4930
# ...

# %%
data.dropna()
# Out:
#         TransactionID  id-01     id-02  id-03  id-04  id-05  id-06  id-07  \
# 118           3664354  -40.0   44218.0    0.0    0.0    6.0  -32.0   26.0
# 248           3665444  -10.0  168694.0    0.0    0.0   -1.0  -25.0   21.0
# 492           3667412   -5.0   45809.0   -2.0   -6.0   22.0  -41.0   11.0
# 986           3671798 -100.0   79259.0    0.0    0.0    0.0  -17.0   11.0
# 1186          3673300  -25.0   69779.0    0.0    0.0    5.0  -31.0   10.0
# ...               ...    ...       ...    ...    ...    ...    ...    ...
# 140132        4165481  -30.0  222844.0    0.0    0.0   15.0  -33.0   29.0
# 140222        4165637  -25.0  131184.0    0.0    0.0    7.0  -34.0   28.0
# 140227        4165666  -45.0   34636.0    0.0    0.0    1.0  -31.0   28.0
# 140604        4166712  -60.0   13187.0    0.0  -12.0   15.0  -64.0    6.0
# 141114        4168134  -15.0   70827.0    0.0    0.0    0.0    0.0    4.0
#
#         id-08  id-09  ...                id-31  id-32      id-33  \
# ...

# %%
data
# Out:
#         TransactionID  id-01     id-02  id-03  id-04  id-05  id-06  id-07  \
# 0             3663586  -45.0  280290.0    NaN    NaN    0.0    0.0    NaN
# 1             3663588    0.0    3579.0    0.0    0.0    0.0    0.0    NaN
# 2             3663597   -5.0  185210.0    NaN    NaN    1.0    0.0    NaN
# 3             3663601  -45.0  252944.0    0.0    0.0    0.0    0.0    NaN
# 4             3663602  -95.0  328680.0    NaN    NaN    7.0  -33.0    NaN
# ...               ...    ...       ...    ...    ...    ...    ...    ...
# 141902        4170230  -20.0  473365.0    NaN    NaN    0.0    0.0    NaN
# 141903        4170233   -5.0  489917.0    0.0    0.0   -4.0  -32.0    NaN
# 141904        4170234   -5.0  110081.0    NaN    NaN   22.0  -31.0    NaN
# 141905        4170236  -45.0  266704.0    NaN    NaN   -3.0  -10.0    NaN
# 141906        4170239  -10.0  692090.0    0.0    0.0    0.0    0.0    NaN
#
#         id-08  id-09  ...                    id-31  id-32     id-33  \
# ...

# %%
data.dropna(thresh=41)
# Out:
#         TransactionID  id-01     id-02  id-03  id-04  id-05  id-06  id-07  \
# 118           3664354  -40.0   44218.0    0.0    0.0    6.0  -32.0   26.0
# 248           3665444  -10.0  168694.0    0.0    0.0   -1.0  -25.0   21.0
# 492           3667412   -5.0   45809.0   -2.0   -6.0   22.0  -41.0   11.0
# 986           3671798 -100.0   79259.0    0.0    0.0    0.0  -17.0   11.0
# 1186          3673300  -25.0   69779.0    0.0    0.0    5.0  -31.0   10.0
# ...               ...    ...       ...    ...    ...    ...    ...    ...
# 140132        4165481  -30.0  222844.0    0.0    0.0   15.0  -33.0   29.0
# 140222        4165637  -25.0  131184.0    0.0    0.0    7.0  -34.0   28.0
# 140227        4165666  -45.0   34636.0    0.0    0.0    1.0  -31.0   28.0
# 140604        4166712  -60.0   13187.0    0.0  -12.0   15.0  -64.0    6.0
# 141114        4168134  -15.0   70827.0    0.0    0.0    0.0    0.0    4.0
#
#         id-08  id-09  ...                id-31  id-32      id-33  \
# ...

# %%
data
# Out:
#         TransactionID  id-01     id-02  id-03  id-04  id-05  id-06  id-07  \
# 0             3663586  -45.0  280290.0    NaN    NaN    0.0    0.0    NaN
# 1             3663588    0.0    3579.0    0.0    0.0    0.0    0.0    NaN
# 2             3663597   -5.0  185210.0    NaN    NaN    1.0    0.0    NaN
# 3             3663601  -45.0  252944.0    0.0    0.0    0.0    0.0    NaN
# 4             3663602  -95.0  328680.0    NaN    NaN    7.0  -33.0    NaN
# ...               ...    ...       ...    ...    ...    ...    ...    ...
# 141902        4170230  -20.0  473365.0    NaN    NaN    0.0    0.0    NaN
# 141903        4170233   -5.0  489917.0    0.0    0.0   -4.0  -32.0    NaN
# 141904        4170234   -5.0  110081.0    NaN    NaN   22.0  -31.0    NaN
# 141905        4170236  -45.0  266704.0    NaN    NaN   -3.0  -10.0    NaN
# 141906        4170239  -10.0  692090.0    0.0    0.0    0.0    0.0    NaN
#
#         id-08  id-09  ...                    id-31  id-32     id-33  \
# ...

# %%
 data.dropna(how = 'all')
# Out:
#         TransactionID  id-01     id-02  id-03  id-04  id-05  id-06  id-07  \
# 0             3663586  -45.0  280290.0    NaN    NaN    0.0    0.0    NaN
# 1             3663588    0.0    3579.0    0.0    0.0    0.0    0.0    NaN
# 2             3663597   -5.0  185210.0    NaN    NaN    1.0    0.0    NaN
# 3             3663601  -45.0  252944.0    0.0    0.0    0.0    0.0    NaN
# 4             3663602  -95.0  328680.0    NaN    NaN    7.0  -33.0    NaN
# ...               ...    ...       ...    ...    ...    ...    ...    ...
# 141902        4170230  -20.0  473365.0    NaN    NaN    0.0    0.0    NaN
# 141903        4170233   -5.0  489917.0    0.0    0.0   -4.0  -32.0    NaN
# 141904        4170234   -5.0  110081.0    NaN    NaN   22.0  -31.0    NaN
# 141905        4170236  -45.0  266704.0    NaN    NaN   -3.0  -10.0    NaN
# 141906        4170239  -10.0  692090.0    0.0    0.0    0.0    0.0    NaN
#
#         id-08  id-09  ...                    id-31  id-32     id-33  \
# ...

# %%
data.isnull().sum()
# Out:
# TransactionID         0
# id-01                 0
# id-02              4931
# id-03             75426
# id-04             75426
# id-05              7157
# id-06              7157
# id-07            136848
# id-08            136848
# id-09             67569
# id-10             67569
# id-11              5129
# id-12                 0
# id-13             11621
# id-14             70550
# id-15              4930
# id-16             16160
# id-17              5941
# id-18             91032
# id-19              6001
# id-20              6274
# id-21            136848
# id-22            136845
# id-23            136845
# id-24            137167
# id-25            136868
# id-26            136860
# id-27            136845
# id-28              5129
# id-29              5129
# id-30             71248
# id-31              5282
# id-32             71236
# id-33             71236
# id-34             69732
# id-35              4930
# id-36              4930
# id-37              4930
# ...

# %%
data.fillna({'id-03':'0','id-04':'1'},inplace=True)

# %%
data.isnull().sum()
# Out:
# TransactionID         0
# id-01                 0
# id-02              4931
# id-03                 0
# id-04                 0
# id-05              7157
# id-06              7157
# id-07            136848
# id-08            136848
# id-09             67569
# id-10             67569
# id-11              5129
# id-12                 0
# id-13             11621
# id-14             70550
# id-15              4930
# id-16             16160
# id-17              5941
# id-18             91032
# id-19              6001
# id-20              6274
# id-21            136848
# id-22            136845
# id-23            136845
# id-24            137167
# id-25            136868
# id-26            136860
# id-27            136845
# id-28              5129
# id-29              5129
# id-30             71248
# id-31              5282
# id-32             71236
# id-33             71236
# id-34             69732
# id-35              4930
# id-36              4930
# id-37              4930
# ...

# %%
data.isnull()
# Out:
#         TransactionID  id-01  id-02  id-03  id-04  id-05  id-06  id-07  id-08  \
# 0               False  False  False  False  False  False  False   True   True
# 1               False  False  False  False  False  False  False   True   True
# 2               False  False  False  False  False  False  False   True   True
# 3               False  False  False  False  False  False  False   True   True
# 4               False  False  False  False  False  False  False   True   True
# ...               ...    ...    ...    ...    ...    ...    ...    ...    ...
# 141902          False  False  False  False  False  False  False   True   True
# 141903          False  False  False  False  False  False  False   True   True
# 141904          False  False  False  False  False  False  False   True   True
# 141905          False  False  False  False  False  False  False   True   True
# 141906          False  False  False  False  False  False  False   True   True
#
# ...

# %%
data.isna().sum()
# Out:
# TransactionID         0
# id-01                 0
# id-02              4931
# id-03                 0
# id-04                 0
# id-05              7157
# id-06              7157
# id-07            136848
# id-08            136848
# id-09             67569
# id-10             67569
# id-11              5129
# id-12                 0
# id-13             11621
# id-14             70550
# id-15              4930
# id-16             16160
# id-17              5941
# id-18             91032
# id-19              6001
# id-20              6274
# id-21            136848
# id-22            136845
# id-23            136845
# id-24            137167
# id-25            136868
# id-26            136860
# id-27            136845
# id-28              5129
# id-29              5129
# id-30             71248
# id-31              5282
# id-32             71236
# id-33             71236
# id-34             69732
# id-35              4930
# id-36              4930
# id-37              4930
# ...

# %%
data.dropna(subset='id-02')
# Out:
#         TransactionID  id-01     id-02 id-03 id-04  id-05  id-06  id-07  \
# 0             3663586  -45.0  280290.0     0     1    0.0    0.0    NaN
# 1             3663588    0.0    3579.0   0.0   0.0    0.0    0.0    NaN
# 2             3663597   -5.0  185210.0     0     1    1.0    0.0    NaN
# 3             3663601  -45.0  252944.0   0.0   0.0    0.0    0.0    NaN
# 4             3663602  -95.0  328680.0     0     1    7.0  -33.0    NaN
# ...               ...    ...       ...   ...   ...    ...    ...    ...
# 141902        4170230  -20.0  473365.0     0     1    0.0    0.0    NaN
# 141903        4170233   -5.0  489917.0   0.0   0.0   -4.0  -32.0    NaN
# 141904        4170234   -5.0  110081.0     0     1   22.0  -31.0    NaN
# 141905        4170236  -45.0  266704.0     0     1   -3.0  -10.0    NaN
# 141906        4170239  -10.0  692090.0   0.0   0.0    0.0    0.0    NaN
#
#         id-08  id-09  ...                    id-31  id-32     id-33  \
# ...
